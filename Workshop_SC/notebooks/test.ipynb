# %%
import qiskit_metal as metal
from qiskit_metal import designs, draw
from qiskit_metal import MetalGUI, Dict, open_docs

# %%
design = designs.DesignPlanar()
gui = MetalGUI(design)
# Out:
# 09:47AM 01s CRITICAL [_qt_message_handler]: line: 0, func: None(), file: None  WARNING: Populating font family aliases took 139 ms. Replace uses of missing font family "Courier" with one that exists to avoid this cost.
# 2025-05-20 09:47:18.834 python[18500:1758040] The class 'NSSavePanel' overrides the method identifier.  This method is implemented by class 'NSWindow'
