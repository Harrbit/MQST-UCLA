# %%
import numpy as np
import matplotlib.pyplot as plt


T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 1.0
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise

fft_signal = np.fft.fft(noisy_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)


# print(f"Calculated SNR: {snr:.2f} dB")

# %% [markdown]
# ## when the window is $10T_2$

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()

# %%
T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 0.5
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise

fft_signal = np.fft.fft(noisy_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)

# %% [markdown]
# ## When the window is $5T_2$

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()

# %%
T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 0.2
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise

fft_signal = np.fft.fft(noisy_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)

# %% [markdown]
# ## When the window is $2T_2$

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()

# %%
T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 0.1
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise

fft_signal = np.fft.fft(noisy_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)

# %% [markdown]
# ## When the window is $T_2$

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()

# %%
T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 0.01
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise

fft_signal = np.fft.fft(noisy_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)

# %% [markdown]
# ## When the window is $0.1T_2$

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()

# %%
T2 = 0.1
f_res = 50
sampling_rate = 10000
duration = 1.0
noise_amplitude = 0.1

time = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)

signal = np.exp(-time / T2) * np.cos(2 * np.pi * f_res * time)

noise = np.random.normal(0, noise_amplitude, size=len(time))
noisy_signal = signal + noise
weight = np.exp(-1/((duration-time)/duration))
weighted_signal = noisy_signal * weight
fft_signal = np.fft.fft(weighted_signal)
frequencies = np.fft.fftfreq(len(time), d=1/sampling_rate)

power_spectrum = np.abs(fft_signal)**2

# Identify the signal in the frequency domain
peak_index = np.argmax(power_spectrum)
half_max = power_spectrum[peak_index] / 2

# Find the Full Width at Half Maximum (FWHM) points
left_idx = np.where(power_spectrum[:peak_index] < half_max)[0][-1]
right_idx = peak_index + np.where(power_spectrum[peak_index:] < half_max)[0][0]

# Sum the power between FWHM points as signal and everything else as noise
signal_power = np.sum(power_spectrum[left_idx:right_idx])
noise_power = np.sum(power_spectrum) - signal_power

snr = 10 * np.log10(signal_power / noise_power)

# %% [markdown]
# ## Weight added

# %%
plt.figure(figsize=(12, 6))
plt.subplot(2, 1, 1)
plt.plot(time, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(time, signal, label='True Signal', linewidth=2, alpha=0.8)
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.title("Time-Domain NMR Signal with Noise")
plt.legend()
plt.grid()
plt.subplot(2, 1, 2)
plt.text(0.95, 0.95, f'SNR: {snr:.2f} dB', verticalalignment='top', horizontalalignment='right', transform=plt.gca().transAxes, color='red', fontsize=12)
plt.plot(frequencies[:len(frequencies)//2], power_spectrum[:len(frequencies)//2], label='Power Spectrum')
plt.xlabel("Frequency (Hz)")
plt.ylabel("Power")
plt.title("Frequency-Domain Power Spectrum")
plt.grid()
plt.tight_layout()
plt.show()
